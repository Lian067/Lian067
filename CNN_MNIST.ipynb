# %% [markdown]
# <a href="https://colab.research.google.com/github/Lian067/Lian067/blob/main/CNN_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CNN for the MNIST Dataset**

# %% [markdown]
# **Import libraries**

# %%
import numpy
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Conv2D, Input, Activation, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model
#from keras.utils import np_utils
from keras.utils import to_categorical

# %%
seed = 7
numpy.random.seed(seed)

# %% [markdown]
# **Load the Dataset**

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
IMG_SHAPE = (28,28,1)

# %% [markdown]
# **normalize inputs from 0-255 to 0-1**

# %%
X_train = X_train / 255
X_test = X_test / 255

# %% [markdown]
# **one hot encode outputs**

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
num_classes = y_test.shape[1]

# %% [markdown]
# **define a simple CNN model**

# %%
def baseline_model(input_shape):
    # create model
    X_input = Input(input_shape)
    X = Conv2D(32,(5,5),strides=(1,1),name='conv0')(X_input)
    X = Activation('relu')(X)
    X = MaxPooling2D((2, 2), name='max_pool0')(X)
    X = Flatten()(X)
    X = Dense(128,activation='relu',name='fc1')(X)
    X = Dense(num_classes, activation='softmax')(X)
    model = Model(inputs = X_input, outputs = X, name='Simple_MnistNet')
    # Compile model
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# %% [markdown]
# **Build the model**

# %%
model = baseline_model(IMG_SHAPE)
model.summary()
# Out:
# Model: "Simple_MnistNet"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv0 (Conv2D)                  │ (None, 24, 24, 32)     │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 24, 24, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pool0 (MaxPooling2D)        │ (None, 12, 12, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4608)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ fc1 (Dense)                     │ (None, 128)            │       589,952 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 592,074 (2.26 MB)
#  Trainable params: 592,074 (2.26 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Train Model**

# %%
print (X_test.shape)
# Out:
# (10000, 28, 28)

# %%
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=1)
# Out:
# Epoch 1/10
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9332 - loss: 0.2375 - val_accuracy: 0.9730 - val_loss: 0.0863
# Epoch 2/10
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9802 - loss: 0.0680 - val_accuracy: 0.9837 - val_loss: 0.0526
# Epoch 3/10
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9859 - loss: 0.0463 - val_accuracy: 0.9848 - val_loss: 0.0512
# Epoch 4/10
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9895 - loss: 0.0344 - val_accuracy: 0.9899 - val_loss: 0.0341
# Epoch 5/10
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9916 - loss: 0.0275 - val_accuracy: 0.9886 - val_loss: 0.0371
# Epoch 6/10
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9933 - loss: 0.0222 - val_accuracy: 0.9880 - val_loss: 0.0401
# Epoch 7/10
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9951 - loss: 0.0166 - val_accuracy: 0.9882 - val_loss: 0.0377
# Epoch 8/10
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9960 - loss: 0.0136 - val_accuracy: 0.9901 - val_loss: 0.0346
# Epoch 9/10
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9968 - loss: 0.0109 - val_accuracy: 0.9876 - val_loss: 0.0389
# Epoch 10/10
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9969 - loss: 0.0102 - val_accuracy: 0.9867 - val_loss: 0.0430

# %% [markdown]
# **Final evaluation of the model**

# %%
scores = model.evaluate(X_test, y_test, verbose=0)
print("CNN Error: %.2f%%" % (100-scores[1]*100))
# Out:
# CNN Error: 1.33%
