# %%
# !git clone https://github.com/Foursteps-tech/Machine_Learning.git
# Out:
# Cloning into 'Machine_Learning'...
# remote: Enumerating objects: 2288, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 2288 (delta 44), reused 81 (delta 27), pack-reused 2173 (from 1)
# Receiving objects: 100% (2288/2288), 84.04 MiB | 25.11 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# Updating files: 100% (2789/2789), done.

# %%
from pandas import read_csv
import numpy as np
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataframe = read_csv("Machine_Learning/Classification/bodyPerformance.csv")
dataframe.head()
# Out:
#     age gender  height_cm  weight_kg  body fat_%  diastolic  systolic  \
# 0  27.0      M      172.3      75.24        21.3       80.0     130.0
# 1  25.0      M      165.0      55.80        15.7       77.0     126.0
# 2  31.0      M      179.6      78.00        20.1       92.0     152.0
# 3  32.0      M      174.5      71.10        18.4       76.0     147.0
# 4  28.0      M      173.8      67.70        17.1       70.0     127.0
#
#    gripForce  sit and bend forward_cm  sit-ups counts  broad jump_cm class
# 0       54.9                     18.4            60.0          217.0     C
# 1       36.4                     16.3            53.0          229.0     A
# 2       44.8                     12.0            49.0          181.0     C
# 3       41.4                     15.2            53.0          219.0     B
# 4       43.5                     27.1            45.0          217.0     B

# %%
le = LabelEncoder()
dataframe['gender'] = le.fit_transform(dataframe['gender'])

# %%
data = dataframe.loc[:, ['age', 'gender', 'height_cm', 'weight_kg',
       'body fat_%', 'diastolic', 'systolic', 'gripForce', 'sit and bend forward_cm',
       'sit-ups counts', 'broad jump_cm']]
labels = dataframe['class']

# %%
(trainData, testData, trainLabels, testLabels) = train_test_split(np.array(data),
	np.array(labels), test_size=0.25, random_state=42)

# %%
#splitter = best, random | max_features = int, auto, log, none | max_depth = int
model = RandomForestClassifier(n_estimators=30, random_state=42,criterion='gini',max_depth=10)

# %%
model.fit(trainData, trainLabels)
# Out:
# RandomForestClassifier(max_depth=10, n_estimators=30, random_state=42)

# %%
print(model.score(trainData, trainLabels))
# Out:
# 0.8359219434488252

# %%
print(model.score(testData, testLabels))
# Out:
# 0.7136458644371454

# %%
predictions = model.predict(testData)

# %%
print(classification_report(testLabels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.71      0.83      0.76       857
#            B       0.57      0.57      0.57       824
#            C       0.69      0.66      0.67       800
#            D       0.89      0.79      0.84       868
#
#     accuracy                           0.71      3349
#    macro avg       0.72      0.71      0.71      3349
# weighted avg       0.72      0.71      0.71      3349

# %%
#splitter = best, random | max_features = int, auto, log, none | max_depth = int
model = RandomForestClassifier(n_estimators=30, random_state=42,criterion='entropy',max_depth=10)

# %%
model.fit(trainData, trainLabels)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=10, n_estimators=30,
#                        random_state=42)

# %%
print(model.score(trainData, trainLabels))
# Out:
# 0.8487654320987654

# %%
print(model.score(testData, testLabels))
# Out:
# 0.7154374440131382

# %%
print(classification_report(testLabels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            A       0.71      0.83      0.76       857
#            B       0.57      0.57      0.57       824
#            C       0.69      0.66      0.67       800
#            D       0.89      0.79      0.84       868
#
#     accuracy                           0.71      3349
#    macro avg       0.72      0.71      0.71      3349
# weighted avg       0.72      0.71      0.71      3349
