# %%
# !git clone https://github.com/Foursteps-tech/Machine_Learning.git
# Out:
# Cloning into 'Machine_Learning'...
# remote: Enumerating objects: 2288, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 2288 (delta 44), reused 81 (delta 27), pack-reused 2173 (from 1)
# Receiving objects: 100% (2288/2288), 84.04 MiB | 17.43 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# Updating files: 100% (2789/2789), done.

# %%
from pandas import read_csv
import numpy as np
import sklearn
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
dataframe = read_csv("Machine_Learning/Classification/mobile_cleaned.csv")
dataframe.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 0              4                     2                 3         67.8
# 1              4                     4                 6         64.0
# 2              4                     9                 6         72.0
# 3              4                     1                 3         75.1
# 4              4                     1                 6         91.0
#
#    expandable_memory  version  usb_type  battery_capacity  processor_rank  \
# 0               64.0        5         3              2000             125
# 1               32.0        5         3              2000             165
# 2               32.0        6         3              2500             164
# 3               32.0        6         3              3000             165
# 4               32.0        6         3              3000             165
#
#    is_liked
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0
#
# [5 rows x 40 columns]

# %%
dataset = dataframe.values


data = dataset[1:,0:38]
labels = dataset[1:,39]

# %%
(trainData, testData, trainLabels, testLabels) = train_test_split(np.array(data),
	np.array(labels), test_size=0.25, random_state=42)

# %%
#penalty = l1, l2, elasticnet
#solver = liblinear, sag, saga, lbfgs, newton-cg
model = LogisticRegression(max_iter=50, solver = 'liblinear')

# %%
model.fit(trainData, trainLabels)
# Out:
# LogisticRegression(max_iter=50, solver='liblinear')

# %%
print(model.score(trainData, trainLabels))
# Out:
# 0.9876543209876543

# %%
print(model.score(testData, testLabels))
# Out:
# 0.5555555555555556

# %%
predictions = model.predict(testData)

# %%
print(classification_report(testLabels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.18      0.40      0.25         5
#          1.0       0.81      0.59      0.68        22
#
#     accuracy                           0.56        27
#    macro avg       0.50      0.50      0.47        27
# weighted avg       0.70      0.56      0.60        27

# %%
#penalty = l1, l2, elasticnet
#solver = liblinear, sag, saga, lbfgs, newton-cg
model = LogisticRegression(max_iter=50, solver = 'saga')

# %%
model.fit(trainData, trainLabels)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# LogisticRegression(max_iter=50, solver='saga')

# %%
print(model.score(trainData, trainLabels))
# Out:
# 0.8518518518518519

# %%
print(model.score(testData, testLabels))
# Out:
# 0.8148148148148148

# %%
predictions = model.predict(testData)

# %%
print(classification_report(testLabels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         5
#          1.0       0.81      1.00      0.90        22
#
#     accuracy                           0.81        27
#    macro avg       0.41      0.50      0.45        27
# weighted avg       0.66      0.81      0.73        27
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
#penalty = l1, l2, elasticnet
#solver = liblinear, sag, saga, lbfgs, newton-cg
model = LogisticRegression(max_iter=100, solver = 'newton-cg')

# %%
model.fit(trainData, trainLabels)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/optimize.py:319: ConvergenceWarning: newton-cg failed to converge at loss = 0.10879137622491955. Increase the number of iterations.
#   warnings.warn(
# LogisticRegression(solver='newton-cg')

# %%
print(model.score(trainData, trainLabels))
# Out:
# 1.0

# %%
print(model.score(testData, testLabels))
# Out:
# 0.6296296296296297

# %%
predictions = model.predict(testData)

# %%
print(classification_report(testLabels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.22      0.40      0.29         5
#          1.0       0.83      0.68      0.75        22
#
#     accuracy                           0.63        27
#    macro avg       0.53      0.54      0.52        27
# weighted avg       0.72      0.63      0.66        27
