# %%
# !git clone https://github.com/Foursteps-tech/Machine_Learning.git
# Out:
# fatal: destination path 'Machine_Learning' already exists and is not an empty directory.

# %%
from pandas import read_csv
import numpy as np
import sklearn
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import tree

# %%
dataframe = read_csv("Machine_Learning/Classification/pima-indians-diabetes.csv",header=None)
dataframe.head()
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
dataframe.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#                 6           7           8
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# 50%      0.372500   29.000000    0.000000
# 75%      0.626250   41.000000    1.000000
# max      2.420000   81.000000    1.000000

# %%
dataset = dataframe.values
data = dataset[:,0:8].astype(float)
labels = dataset[:,8]

# %%
(trainData, testData, trainLabels, testLabels) = train_test_split(np.array(data),
	np.array(labels), test_size=0.25, random_state=42)

# %%
#splitter = best, random | max_features = int, auto, log, none | max_depth = int
model = DecisionTreeClassifier(random_state=42,criterion='gini',max_features=2, max_depth = 3)

# %%
model.fit(trainData, trainLabels)
# Out:
# DecisionTreeClassifier(max_depth=3, max_features=2, random_state=42)

# %%
print(model.score(trainData, trainLabels))
# Out:
# 0.7413194444444444

# %%
print(model.score(testData, testLabels))
# Out:
# 0.7135416666666666

# %%
predictions = model.predict(testData)

# %%
print(classification_report(testLabels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.89      0.80       123
#          1.0       0.68      0.39      0.50        69
#
#     accuracy                           0.71       192
#    macro avg       0.70      0.64      0.65       192
# weighted avg       0.71      0.71      0.69       192

# %%
fig = plt.figure(figsize=(45,40))
fig = tree.plot_tree(model)
plt.show()

# %%
#splitter = best, random | max_features = int, auto, log, none | max_depth = int
model = DecisionTreeClassifier(random_state=42,criterion='entropy',max_features=2, max_depth = 3)

# %%
model.fit(trainData, trainLabels)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, max_features=2,
#                        random_state=42)

# %%
print(model.score(trainData, trainLabels))
# Out:
# 0.7361111111111112

# %%
print(model.score(testData, testLabels))
# Out:
# 0.6979166666666666

# %%
predictions = model.predict(testData)

# %%
print(classification_report(testLabels, predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.86      0.79       123
#          1.0       0.62      0.41      0.49        69
#
#     accuracy                           0.70       192
#    macro avg       0.67      0.63      0.64       192
# weighted avg       0.69      0.70      0.68       192

# %%
fig = plt.figure(figsize=(45,40))
fig = tree.plot_tree(model)
plt.show()
